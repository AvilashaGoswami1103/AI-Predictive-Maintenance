# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\AI-Predictive-Maintenance\memory\out.csv")
data1 = pd.read_csv(r"C:\AI-Predictive-Maintenance\memory\out1.csv")
data2 = pd.read_csv(r"memory\out2.csv")
data.head()
# Out:
#    id                          ts  host_id  cpu_usage_pct  memory_usage_pct  \
# 0   1  2026-04-02 12:22:07.517+00        1            4.0              74.0
# 1   4  2026-04-02 12:24:02.882+00        1            5.0              74.0
# 2   7    2026-04-02 12:26:01.7+00        1            4.0              74.0
# 3  10  2026-04-02 12:28:01.845+00        1            7.0              74.0
# 4  13  2026-04-02 12:30:02.091+00        1            5.0              74.0
#
#    power_kw  status  rolling_mean_1h  rolling_mean_24h  rolling_std_1h  \
# 0     0.220  Normal             74.0              74.0             NaN
# 1     0.220  Normal             74.0              74.0             0.0
# 2     0.221  Normal             74.0              74.0             0.0
# 3     0.220  Normal             74.0              74.0             0.0
# 4     0.221  Normal             74.0              74.0             0.0
#
#    rolling_std_24h  growth_rate  acceleration  Z_score  trend  \
# ...

# %%
for i in [data, data1, data2]:
    i.drop(columns={'power_kw', 'status'}, inplace=True)

data.head()
# Out:
#    id                          ts  host_id  cpu_usage_pct  memory_usage_pct  \
# 0   1  2026-04-02 12:22:07.517+00        1            4.0              74.0
# 1   4  2026-04-02 12:24:02.882+00        1            5.0              74.0
# 2   7    2026-04-02 12:26:01.7+00        1            4.0              74.0
# 3  10  2026-04-02 12:28:01.845+00        1            7.0              74.0
# 4  13  2026-04-02 12:30:02.091+00        1            5.0              74.0
#
#    rolling_mean_1h  rolling_mean_24h  rolling_std_1h  rolling_std_24h  \
# 0             74.0              74.0             NaN              NaN
# 1             74.0              74.0             0.0              0.0
# 2             74.0              74.0             0.0              0.0
# 3             74.0              74.0             0.0              0.0
# 4             74.0              74.0             0.0              0.0
#
#    growth_rate  acceleration  Z_score  trend  volatility_ratio
# ...

# %%
sns.pairplot
